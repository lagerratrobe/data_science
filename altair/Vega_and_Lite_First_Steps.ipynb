# %%
import pandas as pd

df = pd.read_json('cars.json')

# %%
df.head()
# Out:
#    Acceleration  Cylinders  Displacement  Horsepower  Miles_per_Gallon  \
# 0          12.0          8         307.0       130.0              18.0
# 1          11.5          8         350.0       165.0              15.0
# 2          11.0          8         318.0       150.0              18.0
# 3          12.0          8         304.0       150.0              16.0
# 4          10.5          8         302.0       140.0              17.0
#
#                         Name Origin  Weight_in_lbs  Year
# 0  chevrolet chevelle malibu    USA           3504  1970
# 1          buick skylark 320    USA           3693  1970
# 2         plymouth satellite    USA           3436  1970
# 3              amc rebel sst    USA           3433  1970
# 4                ford torino    USA           3449  1970

# %%
from vega import VegaLite

# %%
VegaLite({
  "mark": "point",
  "encoding": {
    "y": {"type": "quantitative","field": "Acceleration"},
    "x": {"type": "quantitative","field": "Horsepower"}
  }
}, df)
# Out:
# <div class="vega-embed" id="8c9d4d06-b4ab-48ec-98d7-2573f3f233f3"></div>
#
# <style>
# .vega-embed svg, .vega-embed canvas {
#   border: 1px dotted gray;
# }
#
# .vega-embed .vega-actions a {
#   margin-right: 6px;
# }
# </style>

# %%
geo_df = pd.read_csv('unemployment.tsv', sep='\t')

# %%
geo_df.head()
# Out:
#      id   rate
# 0  1001  0.097
# 1  1003  0.091
# 2  1005  0.134
# 3  1007  0.121
# 4  1009  0.099

# %%
map_spec = {
  "mark": "geoshape",
  "width": 600,
  "height": 400,
  "projection": {
    "type": "albersUsa"
  },
  "data": {
        "url": "data/us-10m.json",
        "format": {
              "type": "topojson",
              "feature": "states"
                }
          }
}

VegaLite(map_spec)
# Out:
# <div class="vega-embed" id="9e6861a7-a1b2-4420-8a43-e028f1d70834"></div>
#
# <style>
# .vega-embed svg, .vega-embed canvas {
#   border: 1px dotted gray;
# }
#
# .vega-embed .vega-actions a {
#   margin-right: 6px;
# }
# </style>
